# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishekgowdahn/Abhishekgowdahn/blob/main/Processing_image_data_for_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Topics:
# • Reading an image file and converting it to a numpy array
# • Resizing an image &
# • RGB to Grayscale conversion

# %%
#getting an image using web get
# !wget 'https://dogtime.com/wp-content/uploads/sites/12/2020/11/GettyImages-512366437-e1688677726208.jpg?w=1024'
# Out:
# --2025-01-23 08:54:43--  https://dogtime.com/wp-content/uploads/sites/12/2020/11/GettyImages-512366437-e1688677726208.jpg?w=1024
# Resolving dogtime.com (dogtime.com)... 104.16.251.117, 104.16.252.117, 2606:4700::6810:fc75, ...
# Connecting to dogtime.com (dogtime.com)|104.16.251.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34800 (34K) [image/webp]
# Saving to: ‘GettyImages-512366437-e1688677726208.jpg?w=1024’
#
# GettyImages-5123664 100%[===================>]  33.98K  --.-KB/s    in 0.001s
#
# 2025-01-23 08:54:43 (31.4 MB/s) - ‘GettyImages-512366437-e1688677726208.jpg?w=1024’ saved [34800/34800]

# %% [markdown]
# **Libraries that can be used for image processing:
#   1. matplotlib.imgge
#   2. Pillow
#   3. OpenCV(cv2)

# %%
# imoporting image module from matplotlib library
import matplotlib.image as mping
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module
img = mping.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (682, 1024, 3)

# %%
print(img)
# Out:
# [[[165 177 189]
#   [165 177 189]
#   [166 178 190]
#   ...
#   [209 222 227]
#   [209 222 227]
#   [209 222 227]]
#
#  [[165 177 189]
#   [165 177 189]
#   [166 178 190]
#   ...
#   [208 221 226]
#   [208 221 226]
#   [208 221 226]]
#
#  [[165 177 189]
#   [165 177 189]
#   [166 178 190]
#   ...
#   [207 220 225]
#   [207 220 225]
#   [207 220 225]]
#
#  ...
#
#  [[124 114  77]
#   [125 115  78]
#   [126 117  79]
#   ...
#   [235 207 166]
#   [235 207 166]
#   [235 207 166]]
#
#  [[123 113  75]
#   [124 114  77]
#   [126 117  79]
#   ...
#   [235 207 166]
#   [235 207 166]
#   [235 207 166]]
#
#  [[122 112  74]
#   [124 114  77]
#   [126 117  79]
#   ...
#   [234 206 165]
#   [234 206 165]
#   [234 206 165]]]

# %%
# displaying the image from numpy array
img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using Pillow library

# %%
from PIL import Image

# %%
img = Image.open('/content/dog.jpg')
img_resize = img.resize((200,200))

# %%
img_resize.save('dog_image_resize.jpg')

# %%
# displaying the image from numpy array
img_res = mping.imread('/content/dog_image_resize.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# Converting RGB images to Grayscale image using openCV

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (682, 1024, 3)

# %%
grayscale_image = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (682, 1024)

# %% [markdown]
# cv2.imshow() will display the image. but this will not be allowed in Google colab.
# **from google.colab.patches import cv2_imshow**

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=1024x682>

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
